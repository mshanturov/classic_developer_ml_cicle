# %% [markdown]
# # Wheat Seeds Classification\nЭкспериментальный ноутбук в стиле mle-template

# %%
import subprocess\nsubprocess.run(['python3', 'src/preprocess.py'], check=True)\nsubprocess.run(['python3', 'src/train.py', '--model', 'RAND_FOREST', '--use-config', '--predict'], check=True)
